# %% [markdown]
# <a href="https://colab.research.google.com/github/Buvaneshwari26/Cognorise-/blob/main/GenAI1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyA_B43XJyaHaJnhGHKzgg0KDC0XpB5ejT0")

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# ...

# %%
 model=genai.GenerativeModel('gemini-pro')

# %%
model.generate_content(" tell me about indian culture in 50 words").text
# Out:
# 'Indian culture is a vibrant tapestry of ancient traditions, diverse religions, colorful festivals, and rich art forms. From the sacred rituals along the Ganges to the mystical spirituality in the Himalayas, from the intricate designs of henna to the expressive movements of Bharatanatyam dance, Indian culture is a kaleidoscope of customs, beliefs, and artistic expressions that reflect a profound connection to the divine, a deep respect for nature, and an enduring spirit of creativity.'

# %%
model.generate_content(" tell me about indian famous foods in 50 words").text
# Out:
# '1. **Biryani:** Aromatic layered rice dish with meat, vegetables, and fragrant spices.\n2. **Butter Chicken:** Creamy tomato-based gravy dish with tender chicken chunks.\n3. **Dal Makhani:** Rich lentil dish cooked with butter, onions, tomatoes, and spices.\n4. **Dosa:** Crispy fermented rice and lentil pancake, often filled with potatoes or vegetables.\n5. **Gulab Jamun:** Sweet, spongy milk dumplings soaked in sugar syrup.'

# %%
from PIL import Image

# %%
Image.open("/content/APJ-2008.webp")
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=342x450>

# %%
vision_model=genai.GenerativeModel('gemini-1.5-flash')

# %%
res=vision_model.generate_content(["what is in the image",Image.open("/content/APJ-2008.webp")]).text

# %%
res
# Out:
# "That's A.P.J. Abdul Kalam.  The image shows him giving a speech or lecture;  his hands are gesturing, and he appears to be mid-sentence.  He's wearing a grey Nehru jacket.\n"
